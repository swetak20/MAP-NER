# %% [markdown]
# # Pre-processing:
# This is the first sub-module of the `activities_recommendation` module. Firstly we define the purpose of the module and the challenges, then we will dive into the features of the sub-module and then will walkthrough the code.
#
# ## Activities Recommendation
# Each trip consists of a certain number of days. In addition to travel and hotel-stay, the travellers can engage in different activities during their trip. The Activity Recommendation Logic aims to analyze Viator / TripAdvisor activities/attraction data and generate day-wise activity recommendations keeping their schedule, budget and interests in mind.
#
# ### Challenges?
# Even before going into the recommendation channel, there are various challenges we encouter with the initial data we are getting:
#
# #### The expected data for each activity
# - For each activity we need the following data: `num_reviews`, `star_rating`, `prices`, `duration`, `age-group allowed`, `location`, `timings`
# - And, we also need the attraction data to which an activity is mapped to: `attraction_name`, `star_rating`, `num_reviews`, `hours` (availability times), `location`
#
# But in the default data we have activity data without any association with the attraction data -- inshort, we need to map the activities to the attraction data. Moreover, even the viator data alone doesn't suffice all the attributes we need for the activity data -- some of them are present in our 3rd dataset, which is `ta_activity` dataset.
#
# #### The mapping
# Even if we can figure out this much, mapping the activity data to the attraction data is not that straightforward since there is no common column in these two data on which we can do an inner join. Thus, we need to firstly **extract** the names out of the activity data, and then map it to the attraction data. We will see how is that done with the use of `Standford NER Tagger`, and `fuzzy matching`.
#
# #### The optimization
# Even if we can do the mapping properly with matching attributes, there is a lot of data to be mapped, indeed we have about **240 billion** comparisions to do! So we need to optimize the code correctly. Moreover, this adds up one more reason for us to preprocess the data properly.
#
# ## In this sub-module
# In this sub-module we have these two input data sources
# - Trip advisor activities data: From an `os.walk` through the server recursively (around 73,000 entries)
# - Viator activity dataset: Available as a `.csv` file format (around 390,000 entries)
#
# In this sub-module, our aim would be to sanitize the **Viator activity dataset** by removing the null rows. And then map it to the **Trip advisor activities**. This way we would have all the attributes for the activities we need (except `age-groups allowed`, by manual picking and checking of the data, I didn't find this key to be present there). We export the data at each step to `.csv` files for later use. These are the outputs we will have by the end of this sub-module.
# - `TA_ACTS_OS_WALK` (approx. 73,000 entries): Will have the trip advisor activity data from the `os.walk`.
# - `VIATOR_ACTS_CLEANED` (approx. 268,000): Will have the Viator activities after the null rows are removed.
# - `MAPPED_ACT_VIA_TO_TA` (approx. 32,000 entries): Will have the mapped activities from Viator to Trip advisor, will have columns of both of these datasets.
# - `VIATOR_MAPPED_ACTS` (approx. 32,000 entries): Will have the mapped Viator activities -- this will have the columns from the viator dataset alone.
# - `VIATOR_UNMAPPED_ACTS` (approx. 236,000): Will have the unmapped Viator activities.

# %%
# imports and global pandas settings for the notebook
import pandas as pd
import os
import json
pd.options.display.max_columns = None

# input CSV locations
VIATOR_ACTS = '../vapProducts.csv'

# output CSV files to be written
TA_ACTS_OS_WALK = 'ta_activities_os_walk.csv'
VIATOR_ACTS_CLEANED = 'viator_activities_cleaned.csv'
MAPPED_ACT_VIA_TO_TA = 'viator_to_ta_mapped_act.csv'
VIATOR_MAPPED_ACTS = 'viator_mapped_act.csv'
VIATOR_UNMAPPED_ACTS = 'viator_unmapped_act.csv'

# %% [markdown]
# ### Create a DataFrame for TripAdvisor activities
# We do and `os.walk` to get this -- this is the default data source we have with us. We also save it in a csv file for later use as `os.walk` every time is slow.

# %%
# ta_activities data from os walk
data_root_folder = "/mnt/disks/data-01/tapa/activity_index"
TA_DATA_FILE_PATH = data_root_folder + '/raw_data/trip_advisor_products/'
ta_data = []    
for folder, subs, files in os.walk(TA_DATA_FILE_PATH):
    for filename in files:
        with open(os.path.join(folder, filename), 'r') as src:
            for l in src:
                ta_data.append(json.loads(l))
adf = pd.DataFrame(ta_data)

# representation
adf.head(5)
# Out:
#    star_rating detailed_ratings  \
# 0          4.5
# 1          NaN
# 2          4.0
# 3          NaN
# 4          NaN
#
#                                              details certificate tags  \
# 0  [Visit Khor Al Adeid, one of the few places in...
# 1  [Enjoy a desert safari in Qatar, an experience...
# 2  [Go dune bashing in the sandy expanse Qatar's ...
# 3               [ ,  ,  ,  ,  ,  ,  ,  ,  ,  ,  ,  ]
# 4  [Enjoy access to the inland sea of Khor Al Ade...
#
#    num_reviews product_code inside_city_rank  \
# 0          5.0     25649P11
# 1          NaN     52343P19
# 2          1.0      25649P3
# 3          NaN     53513P25
# 4          NaN      52343P2
#
#                                    vendor category  \
# 0  [Qatar International Adventures (QIA)]
# 1                                      []
# 2  [Qatar International Adventures (QIA)]
# 3                        [365 Adventures]
# 4                                      []
#
#                                           highlights  \
# 0  [Full-day private Qatar desert safari from Doh...
# 1                                                 []
# 2  [Overnight accommodation in a luxury Bedouin-s...
# 3                                                 []
# 4  [Hotel pickup and drop-off in Doha, Guided com...
#
#                               similar_activity_names  \
# 0  [Full Day Desert Safari with Lunch or Dinner, ...
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [Full Day Desert Safari with Lunch or Dinner, ...
#
#                                              parents  \
# 0  [Middle East, Qatar, Doha, Places to visit in ...
# 1  [Middle East, Qatar, Doha, Places to visit in ...
# 2  [Middle East, Qatar, Doha, Places to visit in ...
# 3  [Middle East, Qatar, Doha, Places to visit in ...
# 4  [Middle East, Qatar, Doha, Places to visit in ...
#
#                                                 name  \
# 0     Full-day Private Qatar Desert Safari from Doha
# 1        Full Day Desert Safari with Lunch or Dinner
# 2     Desert Safari with Overnight Camping from Doha
# 3                     Education and Sports City Tour
# 4  Inland Sea Desert Safari with BBQ at Souq Al W...
#
#                                             location  \
# 0  {'lng': 51.498245, 'city_id': 294009, 'lat': 2...
# 1  {'lng': 51.458443, 'city_id': 294009, 'lat': 2...
# 2  {'lng': 51.53805, 'city_id': 294009, 'lat': 25...
# 3  {'lng': 51.50022, 'city_id': 294009, 'lat': 25...
# 4  {'lng': 51.486706, 'city_id': 294009, 'lat': 2...
#
#                                         parent_paths  stored_directory  \
# 0  [/Tourism-g21-Middle_East-Vacations.html, /Tou...  21/294008/294009
# 1  [/Tourism-g21-Middle_East-Vacations.html, /Tou...  21/294008/294009
# 2  [/Tourism-g21-Middle_East-Vacations.html, /Tou...  21/294008/294009
# 3  [/Tourism-g21-Middle_East-Vacations.html, /Tou...  21/294008/294009
# 4  [/Tourism-g21-Middle_East-Vacations.html, /Tou...  21/294008/294009
#
#            similar_activity_codes address       price  \
# 0  [12898432, 11988610, 11988619]             € 99.40
# 1                              []          ₹ 7,582.90
# 2                              []          ₹ 9,004.70
# 3                              []          ₹ 3,385.20
# 4  [12898432, 11988610, 11988772]          ₹ 8,192.30
#
#                              parent_ids        current_date  \
# 0  [21, 294008, 294009, 294009, 294009]   1527784859.000944
# 1  [21, 294008, 294009, 294009, 294009]  1527784861.7445896
# 2  [21, 294008, 294009, 294009, 294009]   1527784834.872959
# 3  [21, 294008, 294009, 294009, 294009]  1527784851.8813367
# 4  [21, 294008, 294009, 294009, 294009]  1527784844.6952927
#
#                                          review_desc extra_info  status  \
# 0  [{'rating': 5.0, 'desc': 'Had the BEST day on ...               True
# 1                                                 []               True
# 2  [{'rating': 4.0, 'desc': 'This trip was very e...               True
# 3                                                 []               True
# 4                                                 []               True
#
#                                          description  \
# 0  {'rating': 5.0, 'desc': 'Had the BEST day on t...
# 1                                                 {}
# 2  {'rating': 4.0, 'desc': 'This trip was very ex...
# 3                                                 {}
# 4                                                 {}
#
#                                                  url
# 0  https://www.tripadvisor.in/AttractionProductDe...
# 1  https://www.tripadvisor.in/AttractionProductDe...
# 2  https://www.tripadvisor.in/AttractionProductDe...
# 3  https://www.tripadvisor.in/AttractionProductDe...
# 4  https://www.tripadvisor.in/AttractionProductDe...

# %%
# export ta_activity data as .csv file 
adf.to_csv(TA_ACTIVITIES_OS_WALK, index=False, encoding='utf-8')

# %% [markdown]
# ### Import the Viator activity data:
# Now we will import the data for the viator activities. We set the `low_memory = False` to get rid of the warning of `mixed dtypes`. Then we finally export the cleaned data for later use, this data would be saved in the `viator_activities_cleaned.csv` file.
#
# #### Few notes on this data:
# - **This data has a `ProductCode` column which can be used to map it to the TripAdvisor activities column `product_code`.**
# - About 100k rows of this data are `NaN`, i.e. totally empty. We sanitize the data by removing such columns.

# %%
# data from viator activities
via_df = pd.read_csv(VIATOR_ACTS, low_memory=False)

# clean data by removing the null rows, here if 'ProductCode' is null, then the whole row is null (you can also 
# provide the whole subset of rows here, but for us, this does the job, pretty fast)
via_df.dropna(subset=['ProductCode'], inplace=True)

# export the cleaned data as a csv file
via_df.to_csv(VIATOR_ACTS_CLEANED, index=False, encoding='utf-8')

# representation
via_df.head(5)
# Out:
#    Rank  ProductType  ProductCode  \
# 0     1  SITours_NEW     2280AAHT
# 1     2  SITours_NEW   5022MOULIN
# 2     3  SITours_NEW  3731VATICAN
# 3     4  SITours_NEW  3951WESTDLX
# 4     5  SITours_NEW    2280LI_5H
#
#                                          ProductName  \
# 0          Grand Canyon All-American Helicopter Tour
# 1                     Moulin Rouge Show Ticket Paris
# 2  Faster Than Skip-the-Line: Vatican, Sistine Ch...
# 3  Grand Canyon West Rim and Hoover Dam Tour from...
# 4                Grand Canyon 4-in-1 Helicopter Tour
#
#                                         Introduction  \
# 0  Take off from McCarran Airport on an exhilarat...
# 1  The Moulin Rouge is the number one show in Par...
# 2  Spend more time inside with no-wait access to ...
# 3  Hit the highway out of Las Vegas and spend the...
# 4  Take the ultimate Grand Canyon tour! You'll fl...
#
#                                          ProductText  Special  \
# 0  Take off from McCarran Airport on an exhilarat...        0
# 1  The Moulin Rouge is the number one show in Par...        0
# 2  Spend more time inside with no-wait access to ...        0
# 3  Hit the highway out of Las Vegas and spend the...        0
# 4  Take the ultimate Grand Canyon tour! You'll fl...        0
#
#              Duration                 Commences  \
# 0  3 hours 30 minutes  Las Vegas, United States
# 1             2 hours             Paris, France
# 2             3 hours               Roma, Italy
# 3            12 hours  Las Vegas, United States
# 4  6 hours 30 minutes  Las Vegas, United States
#
#                                         ProductImage  \
# 0  https://media.tacdn.com/media/attractions-spli...
# 1  https://media.tacdn.com/media/attractions-spli...
# 2  https://media.tacdn.com/media/attractions-spli...
# 3  https://media.tacdn.com/media/attractions-spli...
# 4  https://media.tacdn.com/media/attractions-spli...
#
#                                    ProductImageThumb  DestinationID  \
# 0  https://media.tacdn.com/media/attractions-spli...          684.0
# 1  https://media.tacdn.com/media/attractions-spli...          479.0
# 2  https://media.tacdn.com/media/attractions-spli...          511.0
# 3  https://media.tacdn.com/media/attractions-spli...          684.0
# 4  https://media.tacdn.com/media/attractions-spli...          684.0
#
#           Continent        Country         Region       City IATACode  \
# 0  Northern America  United States         Nevada  Las Vegas      LAS
# 1    Western Europe         France  Ile-de-France      Paris      CDG
# 2   Southern Europe          Italy          Lazio       Roma      ROM
# 3  Northern America  United States         Nevada  Las Vegas      LAS
# 4  Northern America  United States         Nevada  Las Vegas      LAS
#
#                             Group1         Category1     Subcategory1  \
# 0  Air, Helicopter & Balloon Tours  Helicopter Tours  Helicopter Tour
# 1         Shows, Concerts & Sports           Cabaret          Cabaret
# 2           Cultural & Theme Tours    Cultural Tours    Cultural Tour
# 3  Air, Helicopter & Balloon Tours  Helicopter Tours  Helicopter Tour
# 4  Air, Helicopter & Balloon Tours  Helicopter Tours  Helicopter Tour
#
#                      Group2                    Category2  \
# 0       Tours & Sightseeing  Self-guided Tours & Rentals
# 1  Shows, Concerts & Sports        Family-friendly Shows
# 2       Tours & Sightseeing               Half-day Tours
# 3       Tours & Sightseeing          Bus & Minivan Tours
# 4       Tours & Sightseeing  Self-guided Tours & Rentals
#
#                   Subcategory2                    Group3  \
# 0            Self Guided Tours       Tours & Sightseeing
# 1  Children's Shows & Concerts  Shows, Concerts & Sports
# 2                Half-day Tour    Walking & Biking Tours
# 3                     Bus Tour        Outdoor Activities
# 4            Self Guided Tours       Tours & Sightseeing
#
#                    Category3        Subcategory3  \
# 0         Audio Guided Tours  Audio Guided Tours
# 1  Theater, Shows & Musicals                Show
# 2              Walking Tours        Walking Tour
# 3  4WD, ATV & Off-Road Tours      Adventure Tour
# 4             Full-day Tours            Day Tour
#
#                                           ProductURL  PriceAUD  PriceNZD  \
# 0  http://www.partner.viator.com/en/66575/tours/L...    637.45    689.81
# 1  http://www.partner.viator.com/en/66575/tours/P...    169.96    183.90
# 2  http://www.partner.viator.com/en/66575/tours/R...    107.07    115.86
# 3  http://www.partner.viator.com/en/66575/tours/L...    183.76    198.86
# 4  http://www.partner.viator.com/en/66575/tours/L...    963.96   1043.14
#
#   PriceEUR  PriceGBP  PriceUSD  PriceCAD  PriceCHF  PriceNOK PriceJPY  \
# 0   381,67    340.92    409.99    583.66    407.34  4 196,38   45,119
# 1   100,00     90.90    111.33    155.60    108.59  1 118,82   12,029
# 2    63,00     57.27     70.14     98.03     68.41    704,86    7,578
# 3   110,02     98.28    118.19    168.25    117.43  1 209,71   13,007
# 4   577,16    515.54    619.99    882.61    615.99  6 345,79   68,230
#
#    PriceSEK  PriceHKD  PriceSGD  PriceZAR  AvgRating  \
# 0   4065.86   3257.12    595.44   7683.23        5.0
# 1   1084.05    847.14    158.74   2048.30        4.5
# 2    682.95    533.70    100.01   1290.43        5.0
# 3   1172.09    938.95    171.65   2214.89        4.5
# 4   6148.42   4925.44    900.43  11618.64        5.0
#
#                                     AvgRatingStarURL        BookingType  \
# 0  http://www.partner.viator.com/images/stars/red...  FreesaleOnRequest
# 1  http://www.partner.viator.com/images/stars/red...          OnRequest
# 2  http://www.partner.viator.com/images/stars/red...           Freesale
# 3  http://www.partner.viator.com/images/stars/red...           Freesale
# 4  http://www.partner.viator.com/images/stars/red...  FreesaleOnRequest
#
#   VoucherOption
# 0     VOUCHER_E
# 1     VOUCHER_E
# 2     VOUCHER_E
# 3     VOUCHER_E
# 4     VOUCHER_E

# %% [markdown]
# ### Merge the two DataFrames:
# - Now we merge these two DataFrames on the basis of matching `ProductCode`, or `product_code`.
# - Export the merged DataFrame as `mapped_activities_via_to_ta.csv`.

# %%
# an inner merge on the two datasets to find the activities with same product code
mapped_act_df = pd.merge(via_df, adf, left_on='ProductCode', right_on='product_code', how='inner')

# %%
# exporting the data to CSV file
mapped_act_df.to_csv(MAPPED_ACT_VIA_TO_TA, index=False, encoding='utf-8')

# %% [markdown]
# ### Distinguish Mapped and Unmapped Viator activities:
# - Now we export these two set of activities in different csv files.
# - For the mapped activities, we have the following extra attributes for an activity
#     - `num_reviews`, `parents` (second last element of the list is the possible attraction name), `location` (holds the coordinates), `extra_info` (might hold other details)
# - The other set of activities (about 90%) will be the other dataset from which we can't map any viator activity and now we will map it to the relevant attraction by NER and string matching techniques later.

# %%
# copy only the relevant columns from the done_act_df
done_act_df = mapped_act_df[['Rank', 'ProductType', 'ProductCode', 'ProductName', 'Introduction',
       'ProductText', 'Special', 'Duration', 'Commences', 'ProductImage',
       'ProductImageThumb', 'DestinationID', 'Continent', 'Country', 'Region',
       'City', 'IATACode', 'Group1', 'Category1', 'Subcategory1', 'Group2',
       'Category2', 'Subcategory2', 'Group3', 'Category3', 'Subcategory3',
       'ProductURL', 'PriceAUD', 'PriceNZD', 'PriceEUR', 'PriceGBP',
       'PriceUSD', 'PriceCAD', 'PriceCHF', 'PriceNOK', 'PriceJPY', 'PriceSEK',
       'PriceHKD', 'PriceSGD', 'PriceZAR', 'AvgRating', 'AvgRatingStarURL',
       'BookingType', 'VoucherOption']].copy()

# drop duplicates, if any
done_act_df.drop_duplicates(inplace=True)

# export done activities for later use with the NER sub-module
done_act_df.to_csv(VIATOR_MAPPED_ACTS, encoding='utf-8', index=False)

# apply mask to via_df dataset (superset) and filter indexes which are exclusive to done_act_df
not_mapped_df = via_df[~via_df.index.isin(done_act_df.index)]
not_mapped_df.head(5)
# Out:
#     Rank  ProductType  ProductCode  \
# 3      4  SITours_NEW  3951WESTDLX
# 4      5  SITours_NEW    2280LI_5H
# 9     10  SITours_NEW   5022MOUDIN
# 10    11  SITours_NEW      2800NYE
# 53    54  SITours_NEW      5516ST1
#
#                                           ProductName  \
# 3   Grand Canyon West Rim and Hoover Dam Tour from...
# 4                 Grand Canyon 4-in-1 Helicopter Tour
# 9           Moulin Rouge Paris Dinner and Show Ticket
# 10    New York City New Year's Eve Circle Line Cruise
# 53       Grand Canyon West Rim Luxury Helicopter Tour
#
#                                          Introduction  \
# 3   Hit the highway out of Las Vegas and spend the...
# 4   Take the ultimate Grand Canyon tour! You'll fl...
# 9   Enjoy an evening dinner show at the Moulin Rou...
# 10  Celebrate the turn of the year in style on thi...
# 53  Travel in five-star style and luxury to one of...
#
#                                           ProductText  Special  \
# 3   Hit the highway out of Las Vegas and spend the...        0
# 4   Take the ultimate Grand Canyon tour! You'll fl...        0
# 9   Enjoy an evening dinner show at the Moulin Rou...        0
# 10  Celebrate the turn of the year in style on thi...        0
# 53  Travel in five-star style and luxury to one of...        0
#
#               Duration                 Commences  \
# 3             12 hours  Las Vegas, United States
# 4   6 hours 30 minutes  Las Vegas, United States
# 9              4 hours             Paris, France
# 10             3 hours   New York, United States
# 53             3 hours  Las Vegas, United States
#
#                                          ProductImage  \
# 3   https://media.tacdn.com/media/attractions-spli...
# 4   https://media.tacdn.com/media/attractions-spli...
# 9   https://media.tacdn.com/media/attractions-spli...
# 10  https://media.tacdn.com/media/attractions-spli...
# 53  https://media.tacdn.com/media/attractions-spli...
#
#                                     ProductImageThumb  DestinationID  \
# 3   https://media.tacdn.com/media/attractions-spli...          684.0
# 4   https://media.tacdn.com/media/attractions-spli...          684.0
# 9   https://media.tacdn.com/media/attractions-spli...          479.0
# 10  https://media.tacdn.com/media/attractions-spli...          687.0
# 53  https://media.tacdn.com/media/attractions-spli...          684.0
#
#            Continent        Country         Region       City IATACode  \
# 3   Northern America  United States         Nevada  Las Vegas      LAS
# 4   Northern America  United States         Nevada  Las Vegas      LAS
# 9     Western Europe         France  Ile-de-France      Paris      CDG
# 10  Northern America  United States       New York   New York      NYC
# 53  Northern America  United States         Nevada  Las Vegas      LAS
#
#                              Group1         Category1     Subcategory1  \
# 3   Air, Helicopter & Balloon Tours  Helicopter Tours  Helicopter Tour
# 4   Air, Helicopter & Balloon Tours  Helicopter Tours  Helicopter Tour
# 9          Shows, Concerts & Sports           Cabaret          Cabaret
# 10         Holiday & Seasonal Tours         New Years    New Years Eve
# 53  Air, Helicopter & Balloon Tours  Helicopter Tours  Helicopter Tour
#
#                             Group2                    Category2  \
# 3              Tours & Sightseeing          Bus & Minivan Tours
# 4              Tours & Sightseeing  Self-guided Tours & Rentals
# 9         Shows, Concerts & Sports    Theater, Shows & Musicals
# 10  Cruises, Sailing & Water Tours                Night Cruises
# 53             Tours & Sightseeing               Full-day Tours
#
#          Subcategory2                      Group3                  Category3  \
# 3            Bus Tour          Outdoor Activities  4WD, ATV & Off-Road Tours
# 4   Self Guided Tours         Tours & Sightseeing             Full-day Tours
# 9                Show    Shows, Concerts & Sports            Dinner Packages
# 10       Night Cruise         Tours & Sightseeing                Night Tours
# 53           Day Tour  Luxury & Special Occasions               Luxury Tours
#
#        Subcategory3                                         ProductURL  \
# 3    Adventure Tour  http://www.partner.viator.com/en/66575/tours/L...
# 4          Day Tour  http://www.partner.viator.com/en/66575/tours/L...
# 9   Dinner and Show  http://www.partner.viator.com/en/66575/tours/P...
# 10      Night Tours  http://www.partner.viator.com/en/66575/tours/N...
# 53     Luxury Tours  http://www.partner.viator.com/en/66575/tours/L...
#
#     PriceAUD  PriceNZD PriceEUR  PriceGBP  PriceUSD  PriceCAD  PriceCHF  \
# 3     183.76    198.86   110,02     98.28    118.19    168.25    117.43
# 4     963.96   1043.14   577,16    515.54    619.99    882.61    615.99
# 9     322.92    349.41   190,00    172.70    211.53    295.64    206.31
# 10    404.25    437.45   242,04    216.20    260.00    370.13    258.32
# 53    513.07    555.21   307,19    274.40    329.99    469.77    327.86
#
#     PriceNOK PriceJPY  PriceSEK  PriceHKD  PriceSGD  PriceZAR  AvgRating  \
# 3   1 209,71   13,007   1172.09    938.95    171.65   2214.89        4.5
# 4   6 345,79   68,230   6148.42   4925.44    900.43  11618.64        5.0
# 9   2 125,76   22,856   2059.70   1609.57    301.61   3891.78        4.5
# 10  2 661,18   28,613   2578.41   2065.54    377.61   4872.41        4.0
# 53  3 377,55   36,315   3272.50   2621.57    479.25   6184.03        5.0
#
#                                      AvgRatingStarURL        BookingType  \
# 3   http://www.partner.viator.com/images/stars/red...           Freesale
# 4   http://www.partner.viator.com/images/stars/red...  FreesaleOnRequest
# 9   http://www.partner.viator.com/images/stars/red...          OnRequest
# 10  http://www.partner.viator.com/images/stars/red...           Freesale
# 53  http://www.partner.viator.com/images/stars/red...  FreesaleOnRequest
#
#    VoucherOption
# 3      VOUCHER_E
# 4      VOUCHER_E
# 9      VOUCHER_E
# 10     VOUCHER_E
# 53     VOUCHER_E

# %%
# export the unmapped data as unmapped_act.csv
not_mapped_df.to_csv(VIATOR_UNMAPPED_ACTS, encoding='utf-8', index=False)

# %% [markdown]
# ### Conclusion
# Now we preprocessed the data for successive sub-modules. We will use the `VIATOR_UNMAPPED_ACTS`, and `VIATOR_MAPPED_ACTS` to extract the possible location names using an NER tagger
